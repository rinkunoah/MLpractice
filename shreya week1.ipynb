# %%
import numpy as np
import pandas as pd
filepath ='C:\IntelPython3\projects\Iris_Data.csv'
print(filepath)
data = pd.read_csv(filepath)
data.head()
# Out:
# C:\IntelPython3\projects\Iris_Data.csv
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.describe()

# %%
data.describe.remove()

# %%
data['describe']=data.describe().max

# %%
data.drop(columns='describe')

# %%
dp=data.describe()

# %%
dp=dp.drop(columns='max-min')

# %%
print(dp.min().values)

# %%
newcol=pd.DataFrame(dp.max().values)

# %%
print(dp.count())

# %%
dp.max

# %%
d = data.describe()

# %%
dic = dict(d)
print(dic)

# %%
for key in dic:
    dic[key]["range"]='{0}-{1}'.format(dic[key]['max'],dic[key]['min'])
a=pd.DataFrame.from_dict(dic)

# %%
type(data.describe())

# %%
data.describe().max

# %%
data.describe().max().values

# %%
data

# %%
data.groupby('species').first()

# %%
data.groupby('species').agg([np.mean,np.median])

# %%
from pprint import pprint

# %%
agg_dict = {field: ['mean', 'median'] for field in data.columns if field != 'species'}

# %%
agg_dict['petal_length']='max'

# %%
pprint(agg_dict)
# Out:
# {'petal_length': 'max',
#  'petal_width': ['mean', 'median'],
#  'sepal_length': ['mean', 'median'],
#  'sepal_width': ['mean', 'median']}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=plt.axes()
a.scatter(data.sepal_length,data.sepal_width)
a.set(xlabel='Sepal length',ylabel='Sepal width',title='sepal len on wid')
p=pd.Series([4.5,5,5.5,6,6.5])
l=pd.Series([2,2.5,3,3.5,4])
a.plot(p,l)

# %%
#a=plt.hist(data.sepal_length,bins=10)
fig, ax = plt.subplots()
ax.barh(np.arange(10),data.sepal_width.iloc[:10])
ax.set_yticks(np.arange(0.4,10.4,1.0))
ax.set_yticklabels(np.arange(1,11))
ax.set(xlabel='sepal width', ylabel='ylabel', title='Title')
# Out:
# [Text(0, 0.5, 'ylabel'), Text(0.5, 0, 'sepal width'), Text(0.5, 1.0, 'Title')]

# %%
import seaborn as sns
a=sns.jointplot(x='sepal_length',y='sepal_width',data=data,height=4)
sns.pairplot(data,hue='species',height=4)
#a.jointplot(x='petal_le(ngth',y='petal_width',title='sore')

# %%
sns.set_context('notebook')

# %%
data.plot.hist(bins=20,alpha=0.5)

# %%
for i in data.hist().flatten():
    print(i)
# Out:
# AxesSubplot(0.125,0.551739;0.336957x0.328261)
# AxesSubplot(0.563043,0.551739;0.336957x0.328261)
# AxesSubplot(0.125,0.125;0.336957x0.328261)
# AxesSubplot(0.563043,0.125;0.336957x0.328261)

# %%
al=data.hist(bins=10)
for i in al.flatten():
    if i.is_last_col():
        print(i)
# Out:
# AxesSubplot(0.563043,0.551739;0.336957x0.328261)
# AxesSubplot(0.563043,0.125;0.336957x0.328261)

# %%
data.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',            medians='DarkBlue', caps='Gray')
data.plot.box(color=color,sym='r+')

# %%
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=plt.axes()
StdSc= StandardScaler()
knn= StdSc.fit(list(zip(data.sepal_length,data.sepal_width)))
print(knn)
X_scaled= knn.transform(list(zip(data.sepal_length,data.sepal_width)))
a.scatter(X_scaled[0],X_scaled[1])
print(X_scaled[0])
data.sepal_length.iloc[0],data.sepal_width.iloc[0]
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [-0.90068117  1.03205722]
# (5.1, 3.5)

# %%
from sklearn.neighbors import KNeighborsClassifier
#Create an instance of the class
KNN= KNeighborsClassifier(n_neighbors=3)
#Fit the instance on the data and then predict the expected value
KNN= KNN.fit(list(zip(data.sepal_length, data.petal_length)),(3,2))
y_predict = KNN.predict(list(zip(data.sepal_length, data.petal_length)))
print(y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-41f0c09f9ea3> in <module>
#       3 KNN= KNeighborsClassifier(n_neighbors=3)
#       4 #Fit the instance on the data and then predict the expected value
# ----> 5 KNN= KNN.fit(list(zip(data.sepal_length, data.petal_length)),(3,2))
#       6 y_predict = KNN.predict(list(zip(data.sepal_length, data.petal_length)))
#       7 print(y_predict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1128         """
#    1129         if not isinstance(X, (KDTree, BallTree)):
# -> 1130             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1131
#    1132         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
KNN= KNeighborsClassifier(n_neighbors=3)
StdSc= StandardScaler()
a=list(zip(data.sepal_length,data.sepal_width))
StdSc= StdSc.fit_transform(a)
StdSc
KNN=KNN.fit(a,data.species)
y_predict=KNN.predict(a)
y_predict
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
